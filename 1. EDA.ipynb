# %%
# Import the Packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/Churn Original.csv").drop(["RowNumber", "Surname"], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerId          10000 non-null  int64
#  1   CreditScore         10000 non-null  int64
#  2   Geography           10000 non-null  object
#  3   Gender              10000 non-null  object
#  4   Age                 10000 non-null  int64
#  5   Tenure              10000 non-null  int64
#  6   Balance             10000 non-null  float64
#  7   NumOfProducts       10000 non-null  int64
#  8   HasCrCard           10000 non-null  int64
#  9   IsActiveMember      10000 non-null  int64
#  10  EstimatedSalary     10000 non-null  float64
#  11  Exited              10000 non-null  int64
#  12  Complain            10000 non-null  int64
#  13  Satisfaction Score  10000 non-null  int64
#  14  Card Type           10000 non-null  object
# ...

# %%
df.describe().round(2)
# Out:
#         CustomerId  CreditScore       Age    Tenure    Balance  NumOfProducts  \
# count     10000.00     10000.00  10000.00  10000.00   10000.00       10000.00
# mean   15690940.57       650.53     38.92      5.01   76485.89           1.53
# std       71936.19        96.65     10.49      2.89   62397.41           0.58
# min    15565701.00       350.00     18.00      0.00       0.00           1.00
# 25%    15628528.25       584.00     32.00      3.00       0.00           1.00
# 50%    15690738.00       652.00     37.00      5.00   97198.54           1.00
# 75%    15753233.75       718.00     44.00      7.00  127644.24           2.00
# max    15815690.00       850.00     92.00     10.00  250898.09           4.00
#
#        HasCrCard  IsActiveMember  EstimatedSalary   Exited  Complain  \
# count   10000.00        10000.00         10000.00  10000.0   10000.0
# mean        0.71            0.52        100090.24      0.2       0.2
# ...

# %%
df[df["Balance"] == 0]["Exited"].value_counts().reset_index()
# Out:
#    Exited  count
# 0       0   3117
# 1       1    500

# %%
df[df["Balance"] > 0]["Exited"].value_counts().reset_index()
# Out:
#    Exited  count
# 0       0   4845
# 1       1   1538

# %%
df["Exited"].value_counts().reset_index()
# Out:
#    Exited  count
# 0       0   7962
# 1       1   2038

# %%
cat_col = df.select_dtypes(include=["object"])
cat_col
# Out:
#      Geography  Gender Card Type
# 0       France  Female   DIAMOND
# 1        Spain  Female   DIAMOND
# 2       France  Female   DIAMOND
# 3       France  Female      GOLD
# 4        Spain  Female      GOLD
# ...        ...     ...       ...
# 9995    France    Male   DIAMOND
# 9996    France    Male  PLATINUM
# 9997    France  Female    SILVER
# 9998   Germany    Male      GOLD
# 9999    France  Female   DIAMOND
#
# [10000 rows x 3 columns]

# %%
sns.catplot(x=df["Card Type"], kind = "count")
sns.catplot(x=df["Gender"], kind = "count")
sns.catplot(x=df["Geography"], kind = "count")

# %%
num_col = df.select_dtypes(exclude=["object"])
num_col
# Out:
#       CustomerId  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 0       15634602          619   42       2       0.00              1
# 1       15647311          608   41       1   83807.86              1
# 2       15619304          502   42       8  159660.80              3
# 3       15701354          699   39       1       0.00              2
# 4       15737888          850   43       2  125510.82              1
# ...          ...          ...  ...     ...        ...            ...
# 9995    15606229          771   39       5       0.00              2
# 9996    15569892          516   35      10   57369.61              1
# 9997    15584532          709   36       7       0.00              1
# 9998    15682355          772   42       3   75075.31              2
# 9999    15628319          792   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0             1               1        101348.88       1         1
# ...

# %%
sns.boxplot(df["Balance"])
# Out:
# <Axes: ylabel='Balance'>

# %%
sns.histplot(data = df, x = "Balance", hue="Exited")
# Out:
# <Axes: xlabel='Balance', ylabel='Count'>

# %%
sns.histplot(data = df , x = "NumOfProducts", hue = "Exited")
df["NumOfProducts"].value_counts().reset_index()
# Out:
#    NumOfProducts  count
# 0              1   5084
# 1              2   4590
# 2              3    266
# 3              4     60

# %%
sns.histplot(data = df , x = "HasCrCard", hue="Exited")
df["HasCrCard"].value_counts().reset_index()
# Out:
#    HasCrCard  count
# 0          1   7055
# 1          0   2945

# %%
sns.histplot(data = df , x = "IsActiveMember", hue="Exited")
df["IsActiveMember"].value_counts().reset_index()
# Out:
#    IsActiveMember  count
# 0               1   5151
# 1               0   4849

# %%
sns.histplot(data = df , x = "EstimatedSalary", hue="Exited")
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Count'>

# %%
sns.boxplot(data = df , y = "Age", hue="Exited")
# Out:
# <Axes: ylabel='Age'>

# %%
sns.histplot(data = df , x = "Complain", hue="Exited", shrink=10)
df["Complain"].value_counts().reset_index()
# Out:
#    Complain  count
# 0         0   7956
# 1         1   2044

# %%
df.pivot_table(index="Complain", columns="Exited", values="CustomerId", aggfunc="count")
# Out:
# Exited       0     1
# Complain
# 0         7952     4
# 1           10  2034

# %%
sns.histplot(data = df , x = "Satisfaction Score", hue="Exited")
df["Satisfaction Score"].value_counts().reset_index()
# Out:
#    Satisfaction Score  count
# 0                   3   2042
# 1                   2   2014
# 2                   4   2008
# 3                   5   2004
# 4                   1   1932

# %%
sns.histplot(data = df , x = "Point Earned", hue="Exited", shrink=1)
# df["Point Earned"].value_counts().reset_index()
# Out:
# <Axes: xlabel='Point Earned', ylabel='Count'>

# %%
# Save the sampled Dataset
df = pd.read_csv("data/Churn Original.csv").drop(["CustomerId","RowNumber", "Surname"], axis = 1)
newdf = pd.concat([df[df["Exited"] == 0].sample(2100), df[df["Exited"] == 1]], axis = 0, ignore_index= True)
newdf.to_csv("data/Churn Sampled.csv", index=False)
